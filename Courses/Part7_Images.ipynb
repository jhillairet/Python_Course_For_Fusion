# %% [markdown]
# # Manipuler des images

# %% [markdown]
# The _scikit-image_ package is a collection of algorithms for image processing. See http://scikit-image.org/ for documentation. See also http://www.scipy-lectures.org/packages/scikit-image/index.html for some other tutorials on scikit-image.

# %%
# %matplotlib inline
from matplotlib.pyplot import *
from numpy import *

# %%
from skimage import data, filters, io

image = data.coins() # or any NumPy array!
edges = filters.sobel(image)
subplot(121)
imshow(image, cmap='gray')
subplot(122)
imshow(edges, cmap='gray')
# Out:
# /Applications/software/mamba/envs/python-3.11/lib/python3.11/site-packages/paramiko/pkey.py:100: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "cipher": algorithms.TripleDES,
# /Applications/software/mamba/envs/python-3.11/lib/python3.11/site-packages/paramiko/transport.py:259: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "class": algorithms.TripleDES,

# %%
IR = io.imread('Image1.png')
imshow(IR)

# %%
print(shape(IR))
r,g,b,k = split(IR, 4, axis=2)
print(shape(r))
subplot(131)
imshow(squeeze(r), cmap='gray')
subplot(132)
imshow(squeeze(g), cmap='gray')
subplot(133)
imshow(squeeze(b), cmap='gray')
# Out:
# (238, 316, 4)
# (238, 316, 1)

# %%
"""Load the CSS sheet 'custom.css' located in the directory"""
from IPython.display import HTML  
styles = f'<style>\n{open("./custom.css","r").read()}\n</style>'
HTML(styles)
# Out:
# <style>
# div.input {
#     width: 105ex; /* about 80 chars + buffer */
# }
#
# .input_prompt, .output_prompt {
#     /*margin-left: 50px;*/
# }
#
# div.text_cell {
#     width: 105ex /* instead of 100%, */
#     margin-left: 0px;
# }
#
# .CodeMirror {
#     font-family: Consolas, monospace;
# }
#
# div.text_cell_render{
#     /*font-family: "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;*/
#     font-family: "Charis SIL", serif; /* Make non-code text serif. */
#     line-height: 145%; /* added for some line spacing of text. */
#     width: 105ex; /* instead of 'inherit' for shorter lines */
#     /*font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;*/
#     font-size: 120%;
#     margin-left:0px;
# }
#
# div.text_cell_render h1 {
# 	font-size: 24pt;
# 	color: rgb(192,80,77);
# 	background-color: rgb(245,245,245);
# }
#
# div.text_cell_render h2 {
# 	font-size: 20pt;
# 	color: rgb(31,73,125);
# 	background-color: rgb(242,242,242);
# }
#
# div.objectives {
#     background-color: #FFFFCC;
#     margin-top: 10px;
#     margin-bottom: 5px;
#     padding: 10px;
#     color: inherit;
#     font-size: 16px;
#     font-family: inherit;
#     font-weight: 500;
#     line-height: 1.1;
#     border: 1px solid;
#     width: 600px;
# }
#
# div.exercice {
#     background-color: #CCCCFF;
#     margin-left: 100px;
#     margin-top: 5px;
#     margin-bottom: 5px;
#     padding: 5px;
#     color: inherit;
#     font-size: 16px;
#     font-family: inherit;
#     line-height: 1.1;
#     border: 1px solid #000;
#     width: 500px;
# }
#
# div.exercice h1{
#     text-align: left;
#     height: 20px;
#     line-height: 20px;
#     font-size: 15px;
#     color: #000;
#     background-color: inherit;
# }
#
# @media print {
# body {-webkit-print-color-adjust: exact;}
# }
# </style>
